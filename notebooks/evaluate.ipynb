# %%
import sys
from pathlib import Path

repo_root = Path.cwd().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
from test_data.valid import valid_profile_descriptions
from moderate import initialize_agent, moderate_profile_description

agent = initialize_agent()

profiles = valid_profile_descriptions[0:2]

for profile in profiles:
    result = moderate_profile_description(profile, agent)
    print(f"Ad: {profile}")
    print(f"Result: {result}")
    print("---")
# Out:
# Ad: Instalator serios pentru reparatii sanitare, montaj baterii, vase WC si scurgeri infundate. Intervin rapid in apartamente si las zona curata dupa lucrare.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 1.0, 'reason': 'Textul este un anunt coerent si profesional pentru servicii de instalatii sanitare, scris corect in limba romana.'}
# ---
# Ad: Electrician autorizat cu experienta in apartamente si case. Montez prize, intrerupatoare, corpuri de iluminat, tablouri electrice si remediez defectiuni aparute pe instalatii vechi.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 1.0, 'reason': 'Textul este coerent, descrie servicii profesionale de electrician și nu conține elemente de spam sau limbaj inadecvat.'}
# ---
