# %%
import sys
from pathlib import Path

repo_root = Path.cwd().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
import importlib

from test_data.valid import valid_profile_descriptions
import moderate

importlib.reload(moderate)

agent = moderate.initialize_agent()

profiles = valid_profile_descriptions[0:10]

count_valid = 0
count_total = 0

invalid = []

for profile in profiles:
    result = moderate.moderate_profile_description(profile, agent)
    print(f"Ad: {profile}")
    print(f"Result: {result}")
    
    count_total += 1

    if result["is_valid"]:
        count_valid += 1
        print(f"Correctly evaluated as valid: {count_valid} out of {count_total}")
    else:
        invalid.append((profile, result))

    print("---")

print(f"Total evaluated as valid: {count_valid} out of {count_total}")

for profile, result in invalid:
    print(f"Incorrectly evaluated as invalid: {profile}")
    print(f"Result: {result}")
    print("---")
# Out:
# Ad: Instalator serios pentru reparatii sanitare, montaj baterii, vase WC si scurgeri infundate. Intervin rapid in apartamente si las zona curata dupa lucrare.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Anunț coerent în limba română, descrie servicii de instalator legitime, fără limbaj ofensator sau conținut neadecvat.'}
# Correctly evaluated as valid: 1 out of 1
# ---
# Ad: Electrician autorizat cu experienta in apartamente si case. Montez prize, intrerupatoare, corpuri de iluminat, tablouri electrice si remediez defectiuni aparute pe instalatii vechi.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text clar și coerent în limba română, descrie servicii profesionale fără conținut ofensator sau caracter evident promoțional excesiv.'}
# Correctly evaluated as valid: 2 out of 2
# ---
# Ad: Zugrav disponibil pentru renovari interioare complete. Execut glet, slefuire, amorsa, lavabila si mici reparatii ale peretilor, cu atentie la curatenie si detalii.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.98, 'reason': 'Text clar și coerent în limba română, oferă un serviciu legitim de zugrăvit/renovări; nu conține limbaj ofensator sau elemente reclamă adeversă.'}
# Correctly evaluated as valid: 3 out of 3
# ---
# Ad: Tamplar mobilier la comanda pentru bucatarie, dressing si dormitor. Ofer masuratori, consultanta pentru compartimentare si montaj ingrijit, adaptat exact spatiului disponibil.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text clar și coerent în limba română; ofertă legitimă de tâmplărie personalizată, fără conținut ofensator sau semne evidente de spam.'}
# Correctly evaluated as valid: 4 out of 4
# ---
# Ad: Faiantar cu experienta in bai si bucatarii.
# Montez gresie, faianta si plinte cu atentie la taieturi si aliniere.
# Pot prelua atat lucrari complete, cat si retusuri locale.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text clar și coerent în limba română care descrie servicii de faianță; nu conține limbaj ofensator sau elemente spam.'}
# Correctly evaluated as valid: 5 out of 5
# ---
# Ad: Montator rigips pentru tavane false, scafe, izolatii si compartimentari. Lucrez curat, respect etapele corecte de montaj si predau lucrarea pregatita pentru finisaj.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text clar și coerent în limba română care descrie servicii profesionale; nu conține limbaj ofensator sau elemente evidente de spam.'}
# Correctly evaluated as valid: 6 out of 6
# ---
# Ad: Sudor si lacatus mecanic pentru porti, balustrade, garduri si reparatii metalice.
# Execut lucrari rezistente si masurate corect, cu accent pe siguranta si durabilitate.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română care descrie servicii profesionale de sudură și lăcătușerie; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 7 out of 7
# ---
# Ad: Parchetar cu experienta in montaj parchet laminat, stratificat si raschetare parchet din lemn. Ofer si servicii de plinte, profile de trecere si lacuire finala.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.98, 'reason': 'Text coerent în limba română care descrie servicii profesionale de montaj parchet; nu conține limbaj ofensator și nu pare a fi spam nejustificat.'}
# Correctly evaluated as valid: 8 out of 8
# ---
# Ad: Tehnician aer conditionat pentru montaj, igienizare si intretinere sezoniera. Verific traseul frigorific, drenajul si parametrii de functionare pentru o utilizare sigura.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Text coerent în română, ofertă legitimă de servicii tehnice (montaj, igienizare, întreținere) fără limbaj ofensator sau elemente de promovare abuzivă.'}
# Correctly evaluated as valid: 9 out of 9
# ---
# Ad: Constructor cu echipa pentru amenajari interioare si exterioare. Executam tencuieli, sape, placari ceramice, zugraveli si renovari complete pentru locuinte si spatii comerciale.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.98, 'reason': 'Text clar în limba română care descrie servicii de construcții/renovare; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 10 out of 10
# ---
# Ad: Geamgiu cu experienta in inlocuire geam spart, geam simplu, oglinda si geam securizat. Ma deplasez rapid pentru masuratori si ofer montaj atent, fara improvizatii.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, anunț legitim de serviciu (geamgiu); fără limbaj ofensator și fără caracter evident de spam.'}
# Correctly evaluated as valid: 11 out of 11
# ---
# Ad: Meserias pentru acoperisuri din tigla sau tabla, disponibil pentru reparatii, inlocuire elemente deteriorate si montaj jgheaburi. Lucrez ordonat si respect normele de siguranta.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, anunț legitim de servicii, fără conținut ofensator sau elemente tipice de spam.'}
# Correctly evaluated as valid: 12 out of 12
# ---
# Ad: Montator usi de interior si exterior, cu experienta in reglaje fine, spuma, toc si accesorii. Ma ocup de montaj complet si remediez probleme de inchidere sau aliniere.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.96, 'reason': 'Text coerent în limba română, descrie profesional un serviciu de montaj uși; nu conține limbaj ofensator sau caracteristici tipice spamului.'}
# Correctly evaluated as valid: 13 out of 13
# ---
# Ad: Instalator centrale termice si calorifere. Montez radiatoare, robineti, distribuitoare si execut modificari de trasee pentru renovari sau configuratii noi in apartamente si case.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.98, 'reason': 'Text coerent în limba română care descrie servicii de instalator; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 14 out of 14
# ---
# Ad: Electrician pentru sisteme smart home, senzori, relee, intrerupatoare inteligente si iluminat controlat din aplicatie. Ofer montaj corect si explic utilizarea dupa finalizare.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Anunț clar și coerent în limba română pentru servicii de electrician smart home; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 15 out of 15
# ---
# Ad: Pietrar pentru placari cu piatra naturala, glafuri, trepte si elemente decorative. Pregatesc suportul corect si urmaresc un finisaj solid, curat si usor de intretinut.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.98, 'reason': 'Text clar și coerent care descrie un serviciu de pietrarie; limbaj adecvat, fără elemente ofensive sau caracter promotional abuziv.'}
# Correctly evaluated as valid: 16 out of 16
# ---
# Ad: Mecanic pentru utilaje mici si scule electrice: motocoase, drujbe, compresoare si generatoare. Fac diagnoza, reparatie si intretinere, cu comunicare clara despre costuri si piese.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent și clar în limba română, descrie o ofertă legitimă de servicii (diagnostic, reparație și întreținere) fără conținut ofensator sau elemente de tip spam.'}
# Correctly evaluated as valid: 17 out of 17
# ---
# Ad: Specialist in garduri metalice si panouri bordurate. Ofer masuratori, montaj stalpi, fixare panouri si porti pietonale, cu solutii practice pentru curti rezidentiale sau firme.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Anunț coerent și clar în limba română care oferă servicii de montaj garduri/panouri; nu conține limbaj ofensator și nu pare a fi spam nejustificat.'}
# Correctly evaluated as valid: 18 out of 18
# ---
# Ad: Montez mobila cumparata din magazine sau realizata la comanda. Asamblez corpuri de bucatarie, dressinguri, paturi si birouri, inclusiv fixari in perete si reglaje finale.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Text clar și coerent care descrie un serviciu de montaj mobilă; nu conține limbaj ofensator sau elemente ce par spam.'}
# Correctly evaluated as valid: 19 out of 19
# ---
# Ad: Finisaje exterioare pentru case si anexe.
# Aplic decorativa, repar fisuri, refac glafuri si zone afectate de umezeala.
# Lucrez atent la protectia suprafetelor si la detalii.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent și clar în limba română, descrie servicii de finisaje exterioare; nu conține conținut ofensator și nu pare a fi spam.'}
# Correctly evaluated as valid: 20 out of 20
# ---
# Ad: Dulgher cu experienta in terase, foisoare, sarpante si structuri usoare din lemn. Aleg solutii rezistente, calculez corect materialele si execut montaj ingrijit.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Anunț coerent, descriptiv al unui meseriaș (dulgher) în limba română; nu conține limbaj ofensator sau elemente de tip spam/gibberish.'}
# Correctly evaluated as valid: 21 out of 21
# ---
# Ad: Specialist in termoizolatii exterioare cu polistiren si vata bazaltica. Montez profile, plasa, masa de spaclu si decorativa, urmarind planeitate si aderenta buna pe termen lung.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie serviciu legitim de termoizolații, fără limbaj ofensator sau semne evidente de spam.'}
# Correctly evaluated as valid: 22 out of 22
# ---
# Ad: Reparator electrocasnice pentru masini de spalat, cuptoare electrice, hote si plite. Identific defectul, explic optiunile de reparatie si intervin doar unde merita economic.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text este un anunț clar și coerent în limba română care descrie servicii de reparații electrocasnice; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 23 out of 23
# ---
# Ad: Sticlar pentru usi de sticla, cabine de dus, oglinzi si compartimentari simple. Ofer masuratori precise si montaj atent, cu accent pe siguranta si aspect final curat.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text clar, coerent în limba română; descrie servicii de sticlarie — nu conține limbaj ofensator și nu pare spam/gibberish.'}
# Correctly evaluated as valid: 24 out of 24
# ---
# Ad: Execut beton amprentat pentru alei, curti si terase. Pregatesc suportul, armajul si finisajul final astfel incat suprafata sa reziste bine la trafic si intemperii.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text coerent și clar în limba română, descrie un serviciu (beton amprentat) fără elemente ofensatoare sau caracteristici tipice spam.'}
# Correctly evaluated as valid: 25 out of 25
# ---
# Ad: Montator ferestre si usi PVC sau aluminiu, inclusiv reglaje, etansare si accesorii. Lucrez corect la spumare si prinderi pentru un montaj stabil si eficient energetic.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română care descrie servicii de montaj; nu conține limbaj ofensator și nu pare a fi spam.'}
# Correctly evaluated as valid: 26 out of 26
# ---
# Ad: Zugrav pentru finisaje decorative speciale.
# Aplic lavabile premium, vopsele decorative si tencuieli cu efect, dupa o pregatire corecta a suportului.
# Ofer mostre si recomandari de culoare.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie servicii profesionale de zugrăvitor fără limbaj ofensator sau caracter evident de spam.'}
# Correctly evaluated as valid: 27 out of 27
# ---
# Ad: Instalator pentru desfundari, inlocuire sifoane, racorduri si remedieri pierderi de apa. Intervin repede, folosesc scule potrivite si explic exact cauza problemei.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text clar și coerent, ofertă de serviciu (instalator), fără limbaj ofensator sau promovare excesivă; se potrivește ca anunț valid.'}
# Correctly evaluated as valid: 28 out of 28
# ---
# Ad: Electrician industrial pentru hale, spatii tehnice si ateliere. Montez tablouri, trasee de cablu, iluminat tehnic si prize de forta, cu respectarea normelor de executie.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Anunț clar și coerent în limba română, descrie servicii profesionale de electrician; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 29 out of 29
# ---
# Ad: Alpinist utilitar pentru montaj burlane, reparatii fatade, etansari si interventii la inaltime. Ofer lucrari sigure, bine planificate, fara montarea unor schele costisitoare.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.97, 'reason': 'Text coerent, profesionist, descrie servicii de alpinism utilitar; nu conține limbaj ofensator și nu pare a fi spam.'}
# Correctly evaluated as valid: 30 out of 30
# ---
# Ad: Montez panouri fotovoltaice pentru locuinte si anexe. Ma ocup de structura, pozitionare, cablare si verificari finale, in colaborare cu electrician autorizat la nevoie.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie un serviciu legitim de instalare panouri fotovoltaice, fără limbaj ofensator sau caracter spam.'}
# Correctly evaluated as valid: 31 out of 31
# ---
# Ad: Faiantar pentru terase, balcoane si scari exterioare. Aleg adezivi si materiale potrivite pentru exterior, tin cont de pante si urmaresc rosturi curate si uniforme.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie un serviciu de faianțare exterior clar și neofensator; nu pare spam.'}
# Correctly evaluated as valid: 32 out of 32
# ---
# Ad: Fierar betonist disponibil pentru fundatii, stalpi, grinzi si placi. Citesc planul, fasonez armatura corect si lucrez organizat pentru a nu intarzia etapele santierului.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, ofertă legitimă de servicii (fierar betonist), fără conținut ofensator sau caracter clar de spam.'}
# Correctly evaluated as valid: 33 out of 33
# ---
# Ad: Execut tencuieli mecanizate sau manuale pentru case, apartamente si spatii comerciale. Pun accent pe planeitate, colturi curate si timpi corecti intre etapele de lucru.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Text coerent, descrie servicii profesionale de tencuieli în română; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 34 out of 34
# ---
# Ad: Repar si montez rulouri exterioare, plase de insecte si sisteme simple de umbrire. Pot inlocui ghidaje, curele, lamele si accesorii uzate, fara batai de cap pentru client.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română care descrie servicii de reparații și montaj; nu conține limbaj ofensator și nu pare a fi spam.'}
# Correctly evaluated as valid: 35 out of 35
# ---
# Ad: Lacatus pentru usi metalice, porti si sisteme de inchidere. Schimb yale, repar balamale, reglez inchideri si execut consolidari pentru cresterea sigurantei.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Anunț clar și coerent despre servicii de lăcătuș (uși metalice, porți, sisteme de închidere), fără limbaj ofensator sau elemente promotive abuzive.'}
# Correctly evaluated as valid: 36 out of 36
# ---
# Ad: Montez seminee decorative si focare, inclusiv placari simple si adaptari ale spatiului. Ofer solutii curate, sigure si proportionate cu dimensiunea incaperii.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.98, 'reason': 'Text coerent în limba română care descrie un serviciu oferit; nu conține limbaj ofensator și pare un anunț legitim, nu spam.'}
# Correctly evaluated as valid: 37 out of 37
# ---
# Ad: Curat si verific cosuri de fum pentru sobe, seminee si centrale pe lemne. Intervin atent, explic riscurile depunerilor si recomand lucrari preventive cand este cazul.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română care descrie clar un serviciu legitim de curățare și verificare a coșurilor; fără conținut ofensator sau caracter evident promotional abuziv.'}
# Correctly evaluated as valid: 38 out of 38
# ---
# Ad: Specialist in hidroizolatii pentru bai, terase, subsoluri si acoperisuri plate. Aplic membrane si sisteme potrivite suportului, urmarind etansare reala si rezistenta in timp.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descriere clară a serviciilor de hidroizolații; nu conține limbaj ofensator și nu pare promoție abuzivă.'}
# Correctly evaluated as valid: 39 out of 39
# ---
# Ad: Execut pavaje pentru curti, alei si trotuare.
# Pregatesc terenul, compactez straturile si montez borduri si pavele cu atentie la pante si scurgerea apei.
# Lucrare curata si durabila.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie servicii de pavaj; nu conține limbaj ofensator sau semne evidente de spam.'}
# Correctly evaluated as valid: 40 out of 40
# ---
# Ad: Placari cu piatra naturala pentru garduri, socluri, seminee si pereti de accent. Lucrez cu grija la selectie, taieturi si montaj, pentru un aspect echilibrat si rezistent.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie un serviciu legitim de placări cu piatră naturală; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 41 out of 41
# ---
# Ad: Instalator autorizat pentru instalatii de gaze, revizii si inlocuiri de componente permise. Respect procedurile de siguranta si lucrez doar cu materiale conforme si verificabile.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie profesional un serviciu (instalator autorizat), fără limbaj ofensator sau elemente neclare; potrivit ca anunț valid.'}
# Correctly evaluated as valid: 42 out of 42
# ---
# Ad: Montez candelabre, lustre mari, benzi LED si iluminat decorativ pentru locuinte sau sali de evenimente. Pot face si mici adaptari ale instalatiei existente pentru un rezultat elegant.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.96, 'reason': 'Text coerent în limba română care descrie servicii de montaj iluminat; nu conține limbaj ofensator și nu pare a fi spam nejustificat.'}
# Correctly evaluated as valid: 43 out of 43
# ---
# Ad: Echipa pentru demolari selective in apartamente si case. Demontam gresie, faianta, rigips, usi si pereti neportanti, cu evacuare moloz si atentie la protejarea zonelor bune.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text clar și coerent în limba română, descrie un serviciu de demolări selective fără conținut ofensator sau tentativă evidentă de promovare agresivă.'}
# Correctly evaluated as valid: 44 out of 44
# ---
# Ad: Repar acoperisuri afectate de vant sau infiltratii. Inlocuiesc elemente deteriorate, refac etansari, jgheaburi si zone sensibile, astfel incat lucrarea sa tina si dupa sezonul rece.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie servicii de reparații acoperișuri; nu conține limbaj ofensator și nu prezintă caracteristici tipice de spam.'}
# Correctly evaluated as valid: 45 out of 45
# ---
# Ad: Vopsitor pentru lemn si metal, disponibil pentru garduri, balustrade, usi, mobilier si elemente decorative. Pregatesc corect suprafata si aleg grundul sau lacul potrivit.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Anunț coerent și descriptiv care promovează un serviciu legitim în limba română, fără limbaj ofensator sau elemente fără sens.'}
# Correctly evaluated as valid: 46 out of 46
# ---
# Ad: Execut carotari si strapungeri controlate pentru instalatii sanitare, electrice sau HVAC. Lucrez cu echipament adecvat, reduc praful si respect pozitiile indicate de beneficiar.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.98, 'reason': 'Text coerent în limba română, descrie servicii profesionale specifice, fără limbaj ofensator sau elemente promoţionale abuzive.'}
# Correctly evaluated as valid: 47 out of 47
# ---
# Ad: Montez si pun in functiune pompe de caldura pentru locuinte unifamiliale. Colaborez bine cu instalatorul si electricianul, iar montajul este facut ordonat si documentat.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie un serviciu profesional de montaj pompe de căldură; nu conține limbaj ofensator și nu pare promotional abuziv.'}
# Correctly evaluated as valid: 48 out of 48
# ---
# Ad: Realizez sape mecanizate sau manuale pentru apartamente, case si spatii comerciale. Urmaresc cotele corecte, compactarea buna si o suprafata pregatita pentru finisaj.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie servicii specifice (realizare șape), fără conținut ofensator și pare un anunț legitim.'}
# Correctly evaluated as valid: 49 out of 49
# ---
# Ad: Montator garduri metalice, porti culisante si porti batante. Ofer masuratori, suduri de fixare, montaj stalpi si reglaje finale pentru functionare usoara si sigura.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.97, 'reason': 'Text coerent în limba română, descrie servicii profesionale de montaj garduri și porți; nu conține conținut ofensator sau caracter evident de spam.'}
# Correctly evaluated as valid: 50 out of 50
# ---
# Ad: Renovez bai complet, de la decopertare pana la montaj obiecte sanitare si finisaj final. Coordonez etapele astfel incat lucrarile sa avanseze logic si fara intarzieri inutile.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text is a coherent Romanian service description for bathroom renovation; not offensive or nonsensical. It is promotional but appropriate for a service listing on a platform.'}
# Correctly evaluated as valid: 51 out of 51
# ---
# Ad: Handyman pentru reparatii mici in locuinta: montaj polite, corpuri de iluminat, perdele, etajere, siliconari, retusuri si alte lucrari pe care multi le amana.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Anunț clar și gramatical corect în limba română care oferă servicii de tip handyman; nu conține limbaj ofensator și este adecvat pentru o platformă de servicii.'}
# Correctly evaluated as valid: 52 out of 52
# ---
# Ad: Montez automatizari pentru porti culisante si batante, inclusiv accesorii de siguranta si telecomenzi. Fac reglaje fine si explic intretinerea de baza dupa punerea in functiune.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.98, 'reason': 'Text coerent în română care descrie servicii de montaj și întreținere pentru porți; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 53 out of 53
# ---
# Ad: Tamplar pentru mobilier de baie si bucatarie, cu accent pe spatii mici si compartimentare practica. Pot adapta corpurile la nise dificile si instalatii deja existente.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie servicii de tâmplărie pentru mobilier de baie și bucătărie; nu conține limbaj ofensator sau elemente de tip spam.'}
# Correctly evaluated as valid: 54 out of 54
# ---
# Ad: Service centrale termice pentru verificari, curatare, aerisire si reglaje uzuale. Intervin punctual, explic simptomele defectelor si recomand doar lucrari cu adevarat necesare.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text este coerent în limba română, descrie servicii profesionale pentru centrale termice fără limbaj ofensator sau conținut promoțional abuziv.'}
# Correctly evaluated as valid: 55 out of 55
# ---
# Ad: Aplic termoizolatii si tencuiala decorativa pentru fatade. Lucrez cu profile, coltare si plasa montate corect, pentru un rezultat drept, curat si rezistent la intemperii.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Text coerent, descrie un serviciu de termoizolații și tencuială pentru fațade în limba română; nu conține limbaj ofensator sau elemente promoționale excesive.'}
# Correctly evaluated as valid: 56 out of 56
# ---
# Ad: Finisor pentru glet, slefuire si pregatirea peretilor inainte de vopsire. Daca suportul este dificil, aleg solutia potrivita pentru a evita fisuri si urme vizibile dupa lavabila.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text is a coherent Romanian description of finishing/sanding walls before painting; contains no offensive content and is a normal service listing, not spam or gibberish.'}
# Correctly evaluated as valid: 57 out of 57
# ---
# Ad: Sudor specializat in inox pentru balustrade, mese de lucru, rame si confectii usoare. Ma intereseaza muchii curate, suduri bine executate si un aspect final profesional.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Anunț clar și coerent în română, descrie serviciu de sudură inox; nu conține limbaj ofensator, nu e text fără sens și nu pare a fi spam agresiv.'}
# Correctly evaluated as valid: 58 out of 58
# ---
# Ad: Montator rigips pentru mansarde, inclusiv izolatie, folie, profile si inchideri corecte in jurul ferestrelor de acoperis. Predau lucrarea gata pentru glet si vopsit.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.98, 'reason': 'Text coerent în limba română care descrie un serviciu de montaj rigips; nu conține limbaj ofensator și nu pare a fi spam.'}
# Correctly evaluated as valid: 59 out of 59
# ---
# Ad: Montez parchet SPC si pardoseli moderne rezistente la umezeala. Corectez mici imperfectiuni ale suportului, montez folia potrivita si urmaresc un finisaj uniform in toate camerele.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie clar un serviciu de montaj pardoseli; nu conține limbaj ofensator sau elemente evidente de promovare agresivă.'}
# Correctly evaluated as valid: 60 out of 60
# ---
# Ad: Instalator pentru spatii horeca, cu experienta in baterii profesionale, sifoane de pardoseala, filtre si adaptari ale retelelor sanitare in bucatarii comerciale.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.98, 'reason': 'Text coerent în limba română, descrie un serviciu profesional pentru spații horeca; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 61 out of 61
# ---
# Ad: Electrician disponibil pentru urgente, inclusiv sigurante cazute, scurtcircuite locale, prize defecte si intrerupatoare arse. Ma deplasez rapid si lucrez cu explicatii clare si costuri transparente.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent și clar, anunț de servicii legitime în limba română, fără conținut ofensator sau indicatori de spam.'}
# Correctly evaluated as valid: 62 out of 62
# ---
# Ad: Repar si refac terase circulabile sau necirculabile. Ma ocup de pante, scurgeri, hidroizolatie si strat de protectie, astfel incat infiltratiile sa nu revina dupa prima ploaie serioasa.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.97, 'reason': 'Text coerent în limba română, descrie servicii profesionale de reparații și hidroizolații; nu conține limbaj ofensator sau caracteristici tipice spam-ului.'}
# Correctly evaluated as valid: 63 out of 63
# ---
# Ad: Confectionez si montez copertine metalice usoare pentru usi, balcoane, vitrine si zone de acces. Solutiile sunt gandite practic, cu fixari sigure si aspect ingrijit.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text is a clear, sensible service description in Romanian without offensive content or promotional excess; fits allowed languages.'}
# Correctly evaluated as valid: 64 out of 64
# ---
# Ad: Montez cabine de dus, rigole, baterii incastrate si mobilier de baie. Lucrez atent la etansare, pante si imbinari, pentru a evita scurgerile si interventiile ulterioare.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text clar, descriere a serviciilor de instalare în limba română; nu conține limbaj ofensator sau elemente de spam.'}
# Correctly evaluated as valid: 65 out of 65
# ---
# Ad: Zugrav pentru case noi sau apartamente renovate recent. Pot prelua lucrari de finisaj final, corectii dupa instalatori sau electricieni si vopsire in doua sau trei straturi.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text clar în limba română, anunț legitim de servicii de zugrăvit și finisaje; nu conține limbaj ofensator și nu este fără sens sau promoție abuzivă.'}
# Correctly evaluated as valid: 66 out of 66
# ---
# Ad: Aplic hidroizolatie in baie inainte de placarea ceramica, cu atentie la colturi, strapungeri si zona de dus. Prefer sa previn problemele de umiditate, nu sa le ascund temporar.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text clar și coerent în limba română; descrie un serviciu de hidroizolație fără conținut ofensator sau tentative de promovare agresivă.'}
# Correctly evaluated as valid: 67 out of 67
# ---
# Ad: Execut confectii din fier forjat si metal pentru balustrade, grilaje, porti si elemente decorative. Pot combina partea practica cu un design simplu si elegant, usor de intretinut.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română; descrie servicii legitime de confecții din metal, nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 68 out of 68
# ---
# Ad: Reconditionez usi si ferestre din lemn prin reparatii locale, chituire, slefuire si revopsire. Pastrez cat mai mult din materialul bun si urmaresc un aspect ingrijit si functional.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Text coerent în limba română care descrie un serviciu de recondiționare; nu conține limbaj ofensator sau caracteristici de spam.'}
# Correctly evaluated as valid: 69 out of 69
# ---
# Ad: Montez lambriu, deck si placari decorative din lemn sau compozit pentru terase si pereti de accent. Lucrez atent la substructura, ventilatie si imbinari curate.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descriere clară a unui serviciu de montaj lambriu/deck/placări; nu conține limbaj ofensator și nu pare spam nejustificat.'}
# Correctly evaluated as valid: 70 out of 70
# ---
# Ad: Ofer mentenanta pentru asociatii de proprietari si cladiri mici: reparatii curente, inlocuiri de corpuri de iluminat, mici lucrari sanitare si interventii punctuale rapide.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.98, 'reason': 'Text coerent în limba română, descrie servicii profesionale de mentenanță; potrivit pentru o platformă de servicii.'}
# Correctly evaluated as valid: 71 out of 71
# ---
# Ad: Reglez termopane, schimb garnituri, manere si feronerie pentru ferestre si usi PVC. Daca problema nu necesita inlocuire completa, caut varianta cea mai eficienta si corecta.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text is a coherent, appropriate Romanian description of services (PVC window/door repair). Nu conține limbaj ofensator sau elemente spam.'}
# Correctly evaluated as valid: 72 out of 72
# ---
# Ad: Mut prize, aplice si intrerupatoare in timpul renovarii, cu trasee gandite curat si pozitionare practica. Ofer si consultanta pentru amplasarea utila a punctelor electrice.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Text coerent în limba română, anunț de servicii electrice clar și relevant, fără conținut ofensator sau caracter spam.'}
# Correctly evaluated as valid: 73 out of 73
# ---
# Ad: Montez obiecte sanitare precum lavoare, cazi, cabine de dus, vase WC suspendate si baterii. Verific etansarea, functionarea si las baia pregatita pentru utilizare imediata.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.97, 'reason': 'Text coerent în limba română, descrie servicii de montaj obiecte sanitare fără conținut ofensator sau promovare abuzivă.'}
# Correctly evaluated as valid: 74 out of 74
# ---
# Ad: Reconditionez mobilier din lemn masiv sau furniruit prin reparatii, consolidari, slefuire si refinisare. Pastrez pe cat posibil caracterul piesei si evit modificarile inutile.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.97, 'reason': 'Text coerent în limba română, descrie un serviciu legitim de recondiționare mobilier; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 75 out of 75
# ---
# Ad: Montez fatade ventilate si placari tehnice pentru proiecte rezidentiale sau comerciale. Respect aliniamentele, substructura si cerintele de montaj pentru un rezultat stabil si curat.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text este o descriere coerenta a unui serviciu în limba română, fără conținut ofensator sau elemente promovare nejustificată.'}
# Correctly evaluated as valid: 76 out of 76
# ---
# Ad: Tehnician pentru instalatii frigorifice mici, vitrine si camere reci. Diagnostic rapid, incarcare agent frigorific unde este permis, inlocuire componente si verificare functionare.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent și clar în limba română, descrie servicii tehnice; nu conține limbaj ofensator și este potrivit pentru o platformă de servicii.'}
# Correctly evaluated as valid: 77 out of 77
# ---
# Ad: Montez rulouri exterioare, plase plisate si sisteme de umbrire pentru ferestre si terase. Ofer masuratori exacte si un montaj care functioneaza lin si fara jocuri.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Anunț coerent în limba română care descrie un serviciu legitim; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 78 out of 78
# ---
# Ad: Aplic microciment in bai, bucatarii si zone decorative. Pregatesc suportul atent, respect timpii de uscare si urmaresc un aspect uniform, modern si usor de intretinut.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română care descrie un serviciu profesional (aplicare microciment) fără conținut ofensator sau semne evidente de spam.'}
# Correctly evaluated as valid: 79 out of 79
# ---
# Ad: Asamblez mobilier modular de tip IKEA, Jysk sau alte branduri, inclusiv corpuri suspendate si ancorare in perete. Lucrez ordonat si verific fiecare reglaj la final.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, anunț legitim pentru servicii de asamblare mobilier, fără limbaj ofensator sau caracter evident spam.'}
# Correctly evaluated as valid: 80 out of 80
# ---
# Ad: Constructor pentru case la rosu: fundatii, zidarie, centuri, plansee si acoperis. Lucrez cu echipa organizata, respect etapele santierului si comunic permanent cu beneficiarul.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în română, anunț legitim de servicii de construcții, fără conținut ofensator sau semne de spam/gibberish.'}
# Correctly evaluated as valid: 81 out of 81
# ---
# Ad: Echipa de finisaje premium pentru apartamente si vile. Oferim pereti foarte bine pregatiti, taieturi curate, rosturi corecte si atentie reala la detaliile care fac diferenta.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text is a coherent Romanian description of finishing services; not offensive or nonsensical and fits allowed languages.'}
# Correctly evaluated as valid: 82 out of 82
# ---
# Ad: Instalator pentru retele sanitare din PPR, cupru sau multistrat. Pot executa trasee noi, modificari pentru renovari si legaturi curate pentru bai, bucatarii sau camere tehnice.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română care descrie servicii de instalator; nu conține limbaj ofensator și nu pare spam sau gibberish.'}
# Correctly evaluated as valid: 83 out of 83
# ---
# Ad: Electrician pentru tablouri electrice, impamantare, protectii diferentiale si reorganizare circuite. Lucrez metodic, etichetez clar si urmaresc functionare sigura pe termen lung.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie servicii de electrician clar și profesional, fără limbaj ofensator sau indicii evidente de spam.'}
# Correctly evaluated as valid: 84 out of 84
# ---
# Ad: Faiantar pentru hoteluri, restaurante si spatii comerciale unde este nevoie de ritm bun si finisaj constant. Respect planul, taieturile repetitive si alinierea pe suprafete mari.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, anunț legitim de servicii (faiantar/placări) pentru spații comerciale; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 85 out of 85
# ---
# Ad: Montez usi de garaj sectionale sau rulou, inclusiv automatizare si accesorii de siguranta. Verific balansul, cursele si etansarea, astfel incat sistemul sa functioneze corect zilnic.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Anunț clar și coerent în limba română, descrie servicii profesionale de montaj și verificare uși de garaj; nu conține limbaj ofensator sau elemente de tip spam.'}
# Correctly evaluated as valid: 86 out of 86
# ---
# Ad: Repar fisuri, desprinderi de tencuiala si infiltratii aparute in jurul ferestrelor sau pe tavane. Urmaresc cauza reala a degradarii si nu fac doar un retus superficial.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.98, 'reason': 'Text clar și coerent în limba română; descrie o ofertă legitimă de servicii de reparații fără limbaj ofensator sau caracter de spam.'}
# Correctly evaluated as valid: 87 out of 87
# ---
# Ad: Reglaje si reparatii pentru tamplarie PVC si aluminiu: feronerie, balamale, manere, inchideri greoaie si etansare slaba. Interventiile sunt rapide si bine explicate.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent în limba română, descrie servicii concrete de reglaje și reparații; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 88 out of 88
# ---
# Ad: Meserias pentru acoperisuri din tabla faltuita sau tigla metalica. Montez folii, accesorii, coame, dolii si sisteme pluviale, cu atentie la detaliile care previn infiltratiile.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.98, 'reason': 'Text is coherent Romanian describing legitimate roofing services, no offensive content or signs of gibberish or spam.'}
# Correctly evaluated as valid: 89 out of 89
# ---
# Ad: Montez camere de supraveghere, DVR, NVR si senzori de baza pentru locuinte, birouri si curti. Traseele sunt ordonate, iar clientul primeste configurare si instructaj clar.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent și clar, ofertă legitimă de servicii tehnice; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 90 out of 90
# ---
# Ad: Instalator cu PFA, disponibil pentru lucrari planificate sau urgente in Bucuresti si imprejurimi. Ma ocup de reparatii, inlocuiri, modificari de trasee si montaj complet pentru baie sau bucatarie.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.98, 'reason': 'Text coerent în limba română, anunț legitim de servicii (instalator PFA) fără limbaj ofensator sau semne de spam.'}
# Correctly evaluated as valid: 91 out of 91
# ---
# Ad: Electrician pentru panouri LED, spoturi, sine magnetice si iluminat comercial. Pot propune pozitii mai eficiente pentru lumina si execut montajul astfel incat totul sa arate curat.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.93, 'reason': 'Text coerent în limba română, descrie servicii de electrician; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 92 out of 92
# ---
# Ad: Finisor pentru glet si decorativa interioara, cu experienta in pereti problematici si tavane dificile. Lucrez cu rabdare, fara graba inutila, pentru un rezultat vizibil bun la lumina naturala.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.98, 'reason': 'Text coerent în limba română, descrie un serviciu profesional fără conținut ofensator sau caracter promoțional abuziv.'}
# Correctly evaluated as valid: 93 out of 93
# ---
# Ad: Pavator pentru curti rezidentiale, alei, parcari si zone de acces. Fac trasare, pregatirea straturilor suport, montaj borduri si compactare, astfel incat suprafata sa nu joace in timp.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text clar, coerent în limba română; descrie servicii de pavare pentru curți, alei și parcări, fără limbaj ofensator sau semne de spam.'}
# Correctly evaluated as valid: 94 out of 94
# ---
# Ad: Montez boilere electrice, instanturi, vase de expansiune si accesorii pentru instalatii sanitare. Verific alimentarea, presiunea si etansarea, apoi explic modul corect de utilizare.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'Romanian', 'confidence': 0.95, 'reason': 'Text coerent şi clar în limba română care descrie servicii tehnice (montaj şi verificare). Nu conţine limbaj ofensator şi nu pare a fi spam abuziv.'}
# Correctly evaluated as valid: 95 out of 95
# ---
# Ad: Repar garduri si porti deformate, stalpi miscati, inchideri slabite si elemente ruginite. Pot face atat consolidari locale, cat si refaceri partiale atunci cand merita economic.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Text clar și coerent în limba română care descrie servicii de reparații; nu este nonsense, nu conține limbaj ofensator sau promovare excesivă.'}
# Correctly evaluated as valid: 96 out of 96
# ---
# Ad: Montez plafoane casetate pentru birouri, magazine si spatii tehnice. Respect modulatia, suspendarea corecta si accesul facil la instalatiile ascunse deasupra tavanului.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romana', 'confidence': 0.95, 'reason': 'Text coerent în română, descrie clar un serviciu profesional; nu conține limbaj ofensator sau elemente tipice de spam.'}
# Correctly evaluated as valid: 97 out of 97
# ---
# Ad: Aplic tapet, fototapet si vinil decorativ pe pereti bine pregatiti. Ma ocup de debitare, aliniere si lipire curata, astfel incat imbinarile sa fie cat mai putin vizibile.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.98, 'reason': 'Text coerent în limba română care descrie clar servicii de aplicare tapet/fototapet/vinil, fără conținut ofensator sau caracter de spam.'}
# Correctly evaluated as valid: 98 out of 98
# ---
# Ad: Service aer conditionat pentru apartamente, birouri si spatii mici comerciale.
# Fac igienizare completa, curatare filtre, verificare presiuni si testare la final.
# Programari rapide in sezon, in limita disponibilitatii.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.95, 'reason': 'Anunț clar și coerent în limba română care descrie un serviciu legitim de întreținere aer condiționat; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 99 out of 99
# ---
# Ad: Echipa pentru renovare completa a locuintei, potrivita cand clientul vrea un singur punct de contact pentru toate etapele. Ne ocupam de decopertari, instalatii sanitare si electrice, rigips, tencuieli, glet, zugraveli, placari ceramice, montaj obiecte sanitare, parchet, usi si retusuri finale. Comunicarea este clara de la inceput, lucram dupa un plan realist si anuntam din timp orice situatie aparuta in santier. Punem pret pe ordine, protectia zonelor comune, aprovizionare organizata si pe predarea unei lucrari curate, functionale si usor de verificat la final.
# Result: {'is_valid': True, 'is_gibberish': False, 'is_spam': False, 'is_inappropriate': False, 'language': 'romanian', 'confidence': 0.96, 'reason': 'Text coerent în limba română, descrie servicii de renovare în mod profesional; nu conține limbaj ofensator și nu pare spam.'}
# Correctly evaluated as valid: 100 out of 100
# ---
# Total evaluated as valid: 100 out of 100
